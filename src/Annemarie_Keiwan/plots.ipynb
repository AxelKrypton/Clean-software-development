# %%
from src.file_handler import get_file_paths
from src.Configurations import load_eggwin, load_siegfried, load_beaktrix
from pathlib import Path
import pandas as pd

eggwin_files = get_file_paths(Path("/Users/bomel/Projects/Clean-software-development/Ising2D/Eggwin/Ising_2D_MCMC_Ns8_Ns8"))
eggwin_frame: pd.DataFrame = pd.concat([load_eggwin(path) for path in eggwin_files])

siegfried_files = get_file_paths(Path("/Users/bomel/Projects/Clean-software-development/Ising2D/Siegfried/two_dimensional_ising_model_markov_chain_monte_carlo_Sz32"))
siegfried_frame: pd.DataFrame = pd.concat([load_siegfried(path) for path in siegfried_files])

# beaktrix_files = get_file_paths(Path("/Users/bomel/Projects/Clean-software-development/Ising2D/Beaktrix/ising2d_L16"))
# beaktrix_frame: pd.DataFrame = pd.concat([load_beaktrix(path) for path in beaktrix_files])

# %%
eggwin_magnetization = eggwin_frame.groupby('temperature').mean()['magnetization_density']
eggwin_magnetization = eggwin_magnetization / eggwin_magnetization.max()
eggwin_magnetization.plot()

siegfried_frame = siegfried_frame.groupby('temperature').mean()['magnetization_density']
siegfried_frame = siegfried_frame / siegfried_frame.max()
siegfried_frame.plot()
# Out:
# <Axes: xlabel='temperature'>

# %%
for temperature in sorted(eggwin_frame["temperature"].unique()):
    temp_frame: pd.DataFrame = eggwin_frame[eggwin_frame["temperature"] == temperature]
    temp_frame.plot.scatter(x="id", y="magnetization_density", title=f"Temperature {temperature}")
# Out:
# /Users/bomel/Projects/Clean-software-development/.venv/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:580: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
